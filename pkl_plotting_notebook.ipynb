# %%
import plotting_pkl_rot_prof

# %%
#This current version uses the much smaller 'x_pred_trace.pkl' files. These only include the surface and core rotation rate as well as p chains.

#I have uploaded the 'x_traces.pkl' zipped. BE WARY THESE ARE NEARLY A GB EACH.
#They have been included for all of the data they contain about the run.


#1 is the true rotational splittings of KIC12508433.

# %%
chains = plotting_pkl_rot_prof.Data(1,1,0.9)

# %%
chains.plot_chains()

# %%
chains.plot_corners()

# %%
chains.plot_corner()

# %%
chains.plot_splitting_predicition()

# %%
chains.plot_profile_predicitions()
